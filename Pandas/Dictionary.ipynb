# %%
people ={
    "first" : ['corey','jane', 'john'],
    "last" : ['ss','doe','doe'],
    "email" : ['cc@gmail.com','jane@gmail.com','john@gmail.com' ]
    
}

# %%
people['email']
# Out:
# ['cc@gmail.com', 'jane@gmail.com', 'john@gmail.com']

# %%
import pandas as pd

# %%
df = pd.DataFrame(people) # creating data frame

# %%
df
# Out:
#    first last           email
# 0  corey   ss    cc@gmail.com
# 1   jane  doe  jane@gmail.com
# 2   john  doe  john@gmail.com

# %% [markdown]
# #access values in  data frame

# %%
df['email']  # df.email
# Out:
# 0      cc@gmail.com
# 1    jane@gmail.com
# 2    john@gmail.com
# Name: email, dtype: object

# %%
type(df['email'])
# Out:
# pandas.core.series.Series

# %%
# series is list of data -- 1 D array -- single column row of data
# data frame -- container for multiple series

# %%
df[['last','email']] # not a series as not single column
# Out:
#   last           email
# 0   ss    cc@gmail.com
# 1  doe  jane@gmail.com
# 2  doe  john@gmail.com

# %%
 df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
#  iloc - to get rows by index --> last value is inclusive


df.iloc[0]
df.iloc[[0,1]]  # to get list of rows
df.iloc[[0,1],2] # to get rows and colums
# Out:
# 0      cc@gmail.com
# 1    jane@gmail.com
# Name: email, dtype: object

# %%
#loc   - to get rows --> last value is inclusive
df.loc[0]
# Out:
# first           corey
# last               ss
# email    cc@gmail.com
# Name: 0, dtype: object

# %%
df.loc[[1,2]]
# Out:
#   first last           email
# 1  jane  doe  jane@gmail.com
# 2  john  doe  john@gmail.com

# %%
df.loc[[0,1],['email','last']]
# Out:
#             email last
# 0    cc@gmail.com   ss
# 1  jane@gmail.com  doe

# %% [markdown]
# # Now go to Pandas Demo till 43

# %%
df['email']
# Out:
# 0      cc@gmail.com
# 1    jane@gmail.com
# 2    john@gmail.com
# Name: email, dtype: object

# %%
# set entity as  index for data frame  - email as index - at first col  -> only view no change in dataset 

df.set_index('email')
# Out:
#                 first last
# email
# cc@gmail.com    corey   ss
# jane@gmail.com   jane  doe
# john@gmail.com   john  doe

# %%
df # no change below
# Out:
#    first last           email
# 0  corey   ss    cc@gmail.com
# 1   jane  doe  jane@gmail.com
# 2   john  doe  john@gmail.com

# %%
df.set_index('email',inplace=True)  # will change dataset

# %%
df  # dataset changed below
# Out:
#                 first last
# email
# cc@gmail.com    corey   ss
# jane@gmail.com   jane  doe
# john@gmail.com   john  doe

# %%
df.index #get list of index and their values
# Out:
# Index(['cc@gmail.com', 'jane@gmail.com', 'john@gmail.com'], dtype='object', name='email')

# %%
df.loc['john@gmail.com']  # work bcz of email as index
# Out:
# first    john
# last      doe
# Name: john@gmail.com, dtype: object

# %%
df.loc['john@gmail.com', 'last']   #give last name for mentioned email
# Out:
# 'doe'

# %%
# This drops the current index completely and replaces it with a fresh 0, 1, 2... index
df.reset_index(drop=True, inplace=True)
df
# Out:
#    first last
# 0  corey   ss
# 1   jane  doe
# 2   john  doe

# %% [markdown]
# ## LEC 4

# %% [markdown]
# ### Filter

# %%
df
# Out:
#    first last
# 0  corey   ss
# 1   jane  doe
# 2   john  doe

# %%
filt = (df['last'] == 'doe')

# %%
df
# Out:
#    first last
# 0  corey   ss
# 1   jane  doe
# 2   john  doe

# %%
df[filt]
# Out:
#   first last
# 1  jane  doe
# 2  john  doe

# %%
df.loc[filt]
# Out:
#   first last
# 1  jane  doe
# 2  john  doe

# %%
df = pd.DataFrame(people) # re-creating original data frame

# %%
df.loc[filt, 'email']
# Out:
# 1    jane@gmail.com
# 2    john@gmail.com
# Name: email, dtype: object

# %%
filt = (df['last'] == 'doe')  & (df['first'] == 'john')
df[filt]
# Out:
#   first last           email
# 2  john  doe  john@gmail.com

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df.columns = ['first_name', 'last_name', 'email']

# %%
df.columns
# Out:
# Index(['first_name', 'last_name', 'email'], dtype='object')

# %%
df.columns =[x.upper() for x in df.columns]  # convert col name to upper case
df
# Out:
#   FIRST_NAME LAST_NAME           EMAIL
# 0      corey        ss    cc@gmail.com
# 1       jane       doe  jane@gmail.com
# 2       john       doe  john@gmail.com

# %%
# replace 
df.columns = df.columns.str.replace('_',' ')
df
# Out:
#   FIRST NAME LAST NAME           EMAIL
# 0      corey        ss    cc@gmail.com
# 1       jane       doe  jane@gmail.com
# 2       john       doe  john@gmail.com

# %%
df.columns = ['first_name', 'last_name', 'email'] # reset to original

# %%
# rename specific col
df.rename(columns = {'first_name': 'first', 'last_name': 'last'}, inplace=True)
df
# Out:
#    first last           email
# 0  corey   ss    cc@gmail.com
# 1   jane  doe  jane@gmail.com
# 2   john  doe  john@gmail.com

# %%
#access rows

# %%
df.loc[2]
# Out:
# first              john
# last                doe
# email    john@gmail.com
# Name: 2, dtype: object

# %%
# chnage value of a col
df.loc[2] = ['john','smith','johns@gmail.com']
df
# Out:
#    first   last            email
# 0  corey     ss     cc@gmail.com
# 1   jane    doe   jane@gmail.com
# 2   john  smith  johns@gmail.com

# %%
#chnage colm by passing colms  name
df.loc[2, ['last','email']] = ['doe','jodoe@gmail.com']
df
# Out:
#    first last            email
# 0  corey   ss     cc@gmail.com
# 1   jane  doe   jane@gmail.com
# 2   john  doe  jodoe@gmail.com

# %%
df.loc[2, 'last'] = 'smith'
df
# Out:
#    first   last            email
# 0  corey     ss     cc@gmail.com
# 1   jane    doe   jane@gmail.com
# 2   john  smith  jodoe@gmail.com

# %%
df.at[2,'last'] = 'simon'
df
# Out:
#    first   last            email
# 0  corey     ss     cc@gmail.com
# 1   jane    doe   jane@gmail.com
# 2   john  simon  jodoe@gmail.com

# %%
df
# Out:
#    first   last            email
# 0  corey     ss     cc@gmail.com
# 1   jane    doe   jane@gmail.com
# 2   john  simon  jodoe@gmail.com

# %%
filt = (df['email'] == 'jodoe@gmail.com')
df[filt]['last'] ='Smith' 
# will throw warning and wont make chnages - see below df line  - due to it's temp chnage and it won't 
# won't work as it's just view  but df.loc will work
# Out:
# C:\Users\SUSAJJIT\AppData\Local\Temp\ipykernel_3700\2508861174.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[filt]['last'] ='Smith'

# %%
df
# Out:
#    first   last            email
# 0  corey     ss     cc@gmail.com
# 1   jane    doe   jane@gmail.com
# 2   john  simon  jodoe@gmail.com

# %%
# will make changes to df
filt = (df['email'] == 'jodoe@gmail.com')
df.loc[filt,'last'] ='smith'

# %%
df
# Out:
#    first   last            email
# 0  corey     ss     cc@gmail.com
# 1   jane    doe   jane@gmail.com
# 2   john  smith  jodoe@gmail.com

# %%
 # show email in lower case
df['email'].str.lower()
# Out:
# 0       cc@gmail.com
# 1     jane@gmail.com
# 2    jodoe@gmail.com
# Name: email, dtype: object

# %% [markdown]
# ## Modification methods in data frame
# 1. apply, 2.map, 3. apply map, 4. replace

# %% [markdown]
# ### 1. Apply

# %%
df['email'].apply(len) #len of email
# Out:
# 0    12
# 1    14
# 2    15
# Name: email, dtype: int64

# %%
#update values - temp

def update_email(email):
    return email.upper()

# %%
df['email'].apply(update_email)
# Out:
# 0       CC@GMAIL.COM
# 1     JANE@GMAIL.COM
# 2    JODOE@GMAIL.COM
# Name: email, dtype: object

# %%
df['email'] = df['email'].apply(update_email) # permannet chnage as assigning

# %%
df
# Out:
#    first   last            email
# 0  corey     ss     CC@GMAIL.COM
# 1   jane    doe   JANE@GMAIL.COM
# 2   john  smith  JODOE@GMAIL.COM

# %%
# lambda func

df['email'] = df['email'].apply(lambda x: x.lower()) # permannet chnage as assigning

# %%
df
# Out:
#    first   last            email
# 0  corey     ss     cc@gmail.com
# 1   jane    doe   jane@gmail.com
# 2   john  smith  jodoe@gmail.com

# %%
df.apply(len)  # len of each colm = no of rows
len(df['email'])  # same as above
# Out:
# 3

# %%
df.apply(len, axis='columns')  # no of colm in each row
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
# min value in each col alphabetically  - it uses ASCII for comparing
df.apply(pd.Series.min) # series is more useful for numerical data
# Out:
# first           corey
# last              doe
# email    cc@gmail.com
# dtype: object

# %%
df.apply(lambda x: x.min()) # series is more useful for numerical data
# Out:
# first           corey
# last              doe
# email    cc@gmail.com
# dtype: object

# %%
# running apply on a series - apply a func to every value in the series
# running apply on a data frame -- apply a func to every series in data frame

# %% [markdown]
# ## 2 applymap

# %%
# applymap - used to apply  a fun to all individual value in data frame
# len of all individual in all the rows and colmns

df.applymap(len)
# Out:
#    first  last  email
# 0      5     2     12
# 1      4     3     14
# 2      4     5     15

# %%
df.applymap(str.lower)
# Out:
#    first   last            email
# 0  corey     ss     cc@gmail.com
# 1   jane    doe   jane@gmail.com
# 2   john  smith  jodoe@gmail.com

# %% [markdown]
# ## 3. map

# %%
# make chnages to a series  -- ; values which are not substituted/assigned below will give NaN

df['first'].map({'corey' : 'Chrish', 'jane': 'Mary'})
# Out:
# 0    Chrish
# 1      Mary
# 2       NaN
# Name: first, dtype: object

# %% [markdown]
# ## 4. Replace

# %%
# keep John but change other -- will chnage what is susbtituted - others will reamin same
df['first'].replace({'corey' : 'Chrish', 'jane': 'Mary'})
# Out:
# 0    Chrish
# 1      Mary
# 2      john
# Name: first, dtype: object

# %%
df['first'].replace({'Steve' : 'steve'})
# Out:
# 0    corey
# 1     jane
# 2     john
# Name: first, dtype: object

# %% [markdown]
# # LEC 6

# %%
# add or remove colm

#combine first and last name and call it full_name
# can't use .(dot) to assign -- python will think - trying to assign an attribute on thr df
# object and not a colmn

df['full_name'] = df['first'] + ' ' + df['last'] # concatanation
df
# Out:
#    first   last            email   full_name
# 0  corey     ss     cc@gmail.com    corey ss
# 1   jane    doe   jane@gmail.com    jane doe
# 2   john  smith  jodoe@gmail.com  john smith

# %%
df.drop(columns ={'first','last'}, inplace = True)

# %%
df
# Out:
#              email   full_name
# 0     cc@gmail.com    corey ss
# 1   jane@gmail.com    jane doe
# 2  jodoe@gmail.com  john smith

# %%
# split full name in first and last

df['full_name'].str.split(' ')
# Out:
# 0      [corey, ss]
# 1      [jane, doe]
# 2    [john, smith]
# Name: full_name, dtype: object

# %%
df['full_name'].str.split(' ', expand = True) # to get splitted values in colms
# Out:
#        0      1
# 0  corey     ss
# 1   jane    doe
# 2   john  smith

# %%
# creating nre colms --  assigning splitted expanded values to new colms
df[['first', 'last']] = df['full_name'].str.split(' ', expand = True)

# %%
df
# Out:
#              email   full_name  first   last
# 0     cc@gmail.com    corey ss  corey     ss
# 1   jane@gmail.com    jane doe   jane    doe
# 2  jodoe@gmail.com  john smith   john  smith

# %%
# Add rows to df

# TypeError: Can only append a dict if ignore_index=True
# df.append({'first' : 'Tony'})  # throw above error - as it doesnt have index currently

df.append({'first' : 'Tony'}, ignore_index=True)
# Out:
# C:\Users\SUSAJJIT\AppData\Local\Temp\ipykernel_3700\2533046534.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append({'first' : 'Tony'}, ignore_index=True)
#              email   full_name  first   last
# 0     cc@gmail.com    corey ss  corey     ss
# 1   jane@gmail.com    jane doe   jane    doe
# 2  jodoe@gmail.com  john smith   john  smith
# 3              NaN         NaN   Tony    NaN

# %%
people ={
    "first" : ['tony','Steve'],
    "last" : ['stark','Rogers'],
    "email" : ['Ironman@gmail.com','Cap@gmail.com']
    
}

df2 = pd.DataFrame(people)

# %%
df2
# Out:
#    first    last              email
# 0   tony   stark  Ironman@gmail.com
# 1  Steve  Rogers      Cap@gmail.com

# %%
# adding rows to data frame from other
# df.append(df2, ignore_index=True) # temp  - append - depricated
# df.append(df2, ignore_index=True) # temp 
pd.concat([df, df2], ignore_index=True)
# Out:
#                email   full_name  first    last
# 0       cc@gmail.com    corey ss  corey      ss
# 1     jane@gmail.com    jane doe   jane     doe
# 2    jodoe@gmail.com  john smith   john   smith
# 3  Ironman@gmail.com         NaN   tony   stark
# 4      Cap@gmail.com         NaN  Steve  Rogers

# %%
# df = df.append(df2, ignore_index=True) # permanent
df = pd.concat([df, df2], ignore_index=True)

# %%
# find the full_name with NaN  value and assign them with cooncat of first and last

df.loc[df['full_name'].isna(), 'full_name'] = df['first'] + ' ' + df['last']

# %%
df
# Out:
#                email     full_name  first    last
# 0       cc@gmail.com      corey ss  corey      ss
# 1     jane@gmail.com      jane doe   jane     doe
# 2    jodoe@gmail.com    john smith   john   smith
# 3  Ironman@gmail.com    tony stark   tony   stark
# 4      Cap@gmail.com  Steve Rogers  Steve  Rogers

# %%
# removing row

df.drop(index = 4)
# Out:
#                email   full_name  first   last
# 0       cc@gmail.com    corey ss  corey     ss
# 1     jane@gmail.com    jane doe   jane    doe
# 2    jodoe@gmail.com  john smith   john  smith
# 3  Ironman@gmail.com  tony stark   tony  stark

# %%
# drop row where last name = doe
# df.drop(index = df[df['last'] == 'doe'].index) # .index used to get index as row operations are performed on index
# below code is just more wrt above - same operarion
filt = df['last'] == 'NaN'
df.drop(index = df[filt].index)
# Out:
#                email     full_name  first    last
# 0       cc@gmail.com      corey ss  corey      ss
# 1     jane@gmail.com      jane doe   jane     doe
# 2    jodoe@gmail.com    john smith   john   smith
# 3  Ironman@gmail.com    tony stark   tony   stark
# 4      Cap@gmail.com  Steve Rogers  Steve  Rogers

# %%
# df = df.drop('Steve')   # to drop a row with index "Steve"

# %% [markdown]
# ## Lec 7

# %% [markdown]
# ### Sorting

# %%
df.sort_values(by='first')  # asc
# Out:
#                email     full_name  first    last
# 4      Cap@gmail.com  Steve Rogers  Steve  Rogers
# 0       cc@gmail.com      corey ss  corey      ss
# 1     jane@gmail.com      jane doe   jane     doe
# 2    jodoe@gmail.com    john smith   john   smith
# 3  Ironman@gmail.com    tony stark   tony   stark

# %%
df.sort_values(by='first', ascending = False)  # desc
# Out:
#                email     full_name  first    last
# 3  Ironman@gmail.com    tony stark   tony   stark
# 2    jodoe@gmail.com    john smith   john   smith
# 1     jane@gmail.com      jane doe   jane     doe
# 0       cc@gmail.com      corey ss  corey      ss
# 4      Cap@gmail.com  Steve Rogers  Steve  Rogers

# %%
#  sort by mutilple params  - if clash on first filter will sort by second and ....

df.sort_values(by = ['last', 'first'], ascending=False) # desc by both param
# Out:
#                email     full_name  first    last
# 3  Ironman@gmail.com    tony stark   tony   stark
# 0       cc@gmail.com      corey ss  corey      ss
# 2    jodoe@gmail.com    john smith   john   smith
# 1     jane@gmail.com      jane doe   jane     doe
# 4      Cap@gmail.com  Steve Rogers  Steve  Rogers

# %%
df.sort_values(by = ['last', 'first'], ascending=[False,True]) # desc - last , asc - first
# Out:
#                email     full_name  first    last
# 3  Ironman@gmail.com    tony stark   tony   stark
# 0       cc@gmail.com      corey ss  corey      ss
# 2    jodoe@gmail.com    john smith   john   smith
# 1     jane@gmail.com      jane doe   jane     doe
# 4      Cap@gmail.com  Steve Rogers  Steve  Rogers

# %%
df.sort_values(by = ['last', 'first'], ascending=[False,True], inplace=True)

# %%
# sort by index - to get in original format
df.sort_index()
# Out:
#                email     full_name  first    last
# 0       cc@gmail.com      corey ss  corey      ss
# 1     jane@gmail.com      jane doe   jane     doe
# 2    jodoe@gmail.com    john smith   john   smith
# 3  Ironman@gmail.com    tony stark   tony   stark
# 4      Cap@gmail.com  Steve Rogers  Steve  Rogers

# %%
# to sort a single col

df['last'].sort_values()
# Out:
# 4    Rogers
# 1       doe
# 2     smith
# 0        ss
# 3     stark
# Name: last, dtype: object

# %% [markdown]
# ## Lec 8

# %% [markdown]
# ## Lec 9

# %%
import pandas as pd

# %%
na_vals = ['NA', 'Missing']
df = pd.read_csv('results.csv', index_col='Respondent', na_values=na_vals) # na_values = nan
schema_df = pd.read_csv('schema.csv', index_col='Column')

# %%
# to display max no of rows and colms
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df['YearsCode'].head(10)
# Out:
# Respondent
# 1       4
# 2     NaN
# 3       3
# 4       3
# 5      16
# 6      13
# 7       6
# 8       8
# 9      12
# 10     12
# Name: YearsCode, dtype: object

# %%
# df['YearsCode'].mean()  # error due to nan float
# TypeError: can only concatenate str (not "int") to str

# casting
# df['YearsCode'] = df['YearsCode'].astype(float) # some values were string 
# ValueError: could not convert string to float: 'Less than 1 year'

# get unique values of colm to see all data types and format them correctly

df['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 'Less than 1 year', '30', '9', '26', '40', '19',
#        '15', '20', '28', '25', '1', '22', '11', '33', '50', '41', '18',
#        '34', '24', '23', '42', '27', '21', '36', '32', '39', '38', '31',
#        '37', 'More than 50 years', '29', '44', '45', '48', '46', '43',
#        '47', '49'], dtype=object)

# %%
# converting diff data type to num
df['YearsCode'].replace('Less than 1 year', 0, inplace=True)
df['YearsCode'].replace('More than 50 years', 51, inplace=True)

# %%
df['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 0, '30', '9', '26', '40', '19', '15', '20', '28',
#        '25', '1', '22', '11', '33', '50', '41', '18', '34', '24', '23',
#        '42', '27', '21', '36', '32', '39', '38', '31', '37', 51, '29',
#        '44', '45', '48', '46', '43', '47', '49'], dtype=object)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].unique()
# Out:
# array([ 4., nan,  3., 16., 13.,  6.,  8., 12.,  2.,  5., 17., 10., 14.,
#        35.,  7.,  0., 30.,  9., 26., 40., 19., 15., 20., 28., 25.,  1.,
#        22., 11., 33., 50., 41., 18., 34., 24., 23., 42., 27., 21., 36.,
#        32., 39., 38., 31., 37., 51., 29., 44., 45., 48., 46., 43., 47.,
#        49.])

# %%
df['YearsCode'].mean()
# Out:
# 11.662114216834588

# %%
df['YearsCode'].median()
# Out:
# 9.0

# %% [markdown]
# ### Lec 10

# %% [markdown]
# ## Lec 11 - Read and write data from/to diff sources

# %%
df = pd.read_csv('results.csv', index_col='Respondent', na_values=na_vals) # na_values = nan
schema_df = pd.read_csv('schema.csv', index_col='Column')

# %%
# to display max no of rows and colms
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows',85)

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
filt = (df['Country'] == 'India')  
india_df = df.loc[filt]  # all respondents from india
india_df.head()
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 8              Less than once per year
# 10          Once a month or more often
# 15                               Never
# 50          Once a month or more often
# 65                               Never
#
#                                                    OpenSource  \
# Respondent
# 8           OSS is, on average, of HIGHER quality than pro...
# 10          OSS is, on average, of HIGHER quality than pro...
# 15          OSS is, on average, of HIGHER quality than pro...
# 50          OSS is, on average, of LOWER quality than prop...
# ...

# %% [markdown]
# ### Exprot data to CSV file

# %%
india_df.to_csv('modified.csv')

# %%
# data separate dy custom delimeter like tab, | etc

india_df.to_csv('modified.tsv', sep ='\t') # tab here

# %% [markdown]
# #### Writing to Excel
# ##### Need to install below packages
# ##### pip install xlwt openpyxl xlrd
# #####  xlwt - for older excel files,  openpyxl -for newer excel files,  xlrd - read and write on excel

# %%
# pip install xlwt openpyxl xlrd
# Out:
# ...
#
# ...
#                                               0.0/100.0 kB ? eta -:--:--
#      -------------------------------------- 100.0/100.0 kB 5.6 MB/s eta 0:00:00
# ...
#                                               0.0/96.6 kB ? eta -:--:--
#      ---------------------------------------- 96.6/96.6 kB 5.4 MB/s eta 0:00:00
# ...

# %%
india_df.to_excel('modified.xlsx')

# %% [markdown]
# ##### Reading from excel file

# %%
test = pd.read_excel('modified.xlsx', index_col = 'Respondent')

# %%
test.head()
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 8              Less than once per year
# 10          Once a month or more often
# 15                               Never
# 50          Once a month or more often
# 65                               Never
#
#                                                    OpenSource  \
# Respondent
# 8           OSS is, on average, of HIGHER quality than pro...
# 10          OSS is, on average, of HIGHER quality than pro...
# 15          OSS is, on average, of HIGHER quality than pro...
# 50          OSS is, on average, of LOWER quality than prop...
# ...

# %% [markdown]
# ###  Read and Write  on JSON

# %%
# india_df.to_json('modified.json')

# %%
# to make json list(array) like rather than dictionary ({{}}) like
# lines=True (gave error) - put each of orient = 'records' on a new  line

# india_df.to_json('modified1.json', orient = 'records', lines=False)

# %%
# Read from json
# test = pd.read_json('modified.json', orient = 'records', lines=False)

# %%
# test.head()
# Out:
#                                 MainBranch Hobbyist  \
# 8              I code primarily as a hobby      Yes
# 10          I am a developer by profession      Yes
# 15  I am a student who is learning to code      Yes
# 50          I am a developer by profession      Yes
# 65          I am a developer by profession      Yes
#
#                    OpenSourcer  \
# 8      Less than once per year
# 10  Once a month or more often
# 15                       Never
# 50  Once a month or more often
# 65                       Never
#
#                                            OpenSource  \
# 8   OSS is, on average, of HIGHER quality than pro...
# 10  OSS is, on average, of HIGHER quality than pro...
# 15  OSS is, on average, of HIGHER quality than pro...
# 50  OSS is, on average, of LOWER quality than prop...
# 65                                               None
#
#                             Employment Country         Student  \
# ...

# %% [markdown]
# ### Read and Write on SQL DB

# %%
# Package required
# !pip install SQLAlchemy

# %%
# for working with postgres
# !pip install psycopg2-binary
# Out:
# ...
#                                               0.0/2.8 MB ? eta -:--:--
#      ------                                   0.4/2.8 MB 13.2 MB/s eta 0:00:01
#      ----------------------                   1.5/2.8 MB 19.6 MB/s eta 0:00:01
#      ---------------------------------------  2.8/2.8 MB 24.9 MB/s eta 0:00:01
#      ---------------------------------------- 2.8/2.8 MB 22.0 MB/s eta 0:00:00
# ...

# %%
# from sqlalchemy import create_engine # for connecting to db
# import psycopg2

# %%
# %pip install pyodbc

# %%
# import urllib
# import pandas as pd
# from sqlalchemy import create_engine

# # 1. Your connection parameters
# DB_SERVER = r"SS\SQLEXPRESS"
# DB_NAME = "Pandas_test"
# DB_USER = ""
# DB_PASSWORD = ""

# # 2. Re-create the connection string using ODBC Driver 17
# if DB_USER and DB_PASSWORD:
#     odbc_str = (
#         f"DRIVER={{ODBC Driver 17 for SQL Server}};"
#         f"SERVER={DB_SERVER};DATABASE={DB_NAME};"
#         f"UID={DB_USER};PWD={DB_PASSWORD}"
#     )
# else:
#     odbc_str = (
#         f"DRIVER={{ODBC Driver 17 for SQL Server}};"
#         f"SERVER={DB_SERVER};DATABASE={DB_NAME};"
#         f"Trusted_Connection=yes;"
#     )

# params = urllib.parse.quote_plus(odbc_str)
# connection_string = f"mssql+pyodbc:///?odbc_connect={params}"
# engine = create_engine(connection_string) # db connection
# Out:
# 🎉 Success! The table 'scraped_companies' has been created and populated.

# %%
# exporting/writing to db

# india_df.to_sql('Sample_table', engine)

# %% [markdown]
# #### read from db

# %%
# # read from db
# from sqlalchemy import text

# # 1. Wrap the table query using text()
# # (Using a standard SELECT statement lets us fetch the table safely)
# query = text("SELECT * FROM Sample_table")

# # 2. Use the modern context manager to read it out safely
# with engine.connect() as conn:
#     sql_df = pd.read_sql(query, con=conn, index_col="Respondent")

# # View your newly loaded DataFrame with its custom index
# sql_df.head()
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 8              Less than once per year
# 10          Once a month or more often
# 15                               Never
# 50          Once a month or more often
# 65                               Never
#
#                                                    OpenSource  \
# Respondent
# 8           OSS is, on average, of HIGHER quality than pro...
# 10          OSS is, on average, of HIGHER quality than pro...
# 15          OSS is, on average, of HIGHER quality than pro...
# 50          OSS is, on average, of LOWER quality than prop...
# ...

# %%
sql_df.head()
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 8              Less than once per year
# 10          Once a month or more often
# 15                               Never
# 50          Once a month or more often
# 65                               Never
#
#                                                    OpenSource  \
# Respondent
# 8           OSS is, on average, of HIGHER quality than pro...
# 10          OSS is, on average, of HIGHER quality than pro...
# 15          OSS is, on average, of HIGHER quality than pro...
# 50          OSS is, on average, of LOWER quality than prop...
# ...

# %% [markdown]
# #### running read query on db

# %%
# 1. Explicitly wrap your query string in text()
query = text("SELECT * FROM Sample_table")

# 2. Pass the executable text object into read_sql_query
with engine.connect() as conn:
    sql_df = pd.read_sql_query(query, con=conn, index_col="Respondent")

# View your data
sql_df.head()

# or using below code

# No raw SQL or text() wrappers required for this one
with engine.connect() as conn:
    sql_df = pd.read_sql_table(
        "Sample_table", con=conn, index_col="Respondent"
    )

# %% [markdown]
# ### Reading data from URL

# %%
# Use the direct raw text URL instead of the user interface page link
url = "https://raw.githubusercontent.com/CoreyMSchafer/code_snippets/master/Python/Flask_Blog/snippets/posts.json"


# json as file we are trying to read is JSON
posts_df = pd.read_json(url)

# View the downloaded data
posts_df.head()
# Out:
#                           title  \
# 0               My Updated Post
# 1                 A Second Post
# 2  Top 5 Programming Lanaguages
# 3  Sublime Text Tips and Tricks
# 4              Best Python IDEs
#
#                                              content  user_id
# 0    My first updated post!\r\n\r\nThis is exciting!        1
# 1            This is a post from a different user...        2
# 2  Te melius apeirian postulant cum, labitur admo...        1
# 3  Ea vix dico modus voluptatibus, mel iudico sua...        1
# 4  Elit contentiones nam no, sea ut consul adipis...        1

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[158], line 1
# ----> 1 posts_df.head()
#
# NameError: name 'posts_df' is not defined
