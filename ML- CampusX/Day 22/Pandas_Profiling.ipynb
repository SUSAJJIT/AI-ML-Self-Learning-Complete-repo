# %% [markdown]
# <a href="https://colab.research.google.com/github/SUSAJJIT/AI-ML-Self-Learning-Complete-repo/blob/main/ML-%20CampusX/Day%2022/Pandas_Profiling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Pandas Profiling**
#
# Library used to automate lot's of things that we did in Lec 21

# %%
import pandas as pd

# %%
#  installing pandas profiler

# !pip install pandas-profiling    - deprecated

# !pip uninstall pandas-profiling visions -y

# installing updated version of pandas-profiling
# !pip install ydata-profiling

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
from ydata_profiling import ProfileReport
prof = ProfileReport(df)  # create a report
prof.to_file(output_file='output.html') # create an output file
# Out:
# ...
# 100%|██████████| 12/12 [00:00<00:00, 30.27it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4948/2094424732.py in <cell line: 0>()
#       1 from ydata_profiling import ProfileReport
#       2 prof = ProfileReport(df)  # create a report
# ----> 3 prof.to_file(output_file='output.html') # create an output file
#
# /usr/local/lib/python3.12/dist-packages/ydata_profiling/profile_report.py in to_file(self, output_file, silent)
#     379                 create_html_assets(self.config, output_file)
#     380
# --> 381             data = self.to_html()
#     382
#     383             if output_file.suffix != ".html":
#
# /usr/local/lib/python3.12/dist-packages/ydata_profiling/profile_report.py in to_html(self)
#     496
#     497         """
# --> 498         return self.html
#     499
#     500     def to_json(self) -> str:
#
# ...
