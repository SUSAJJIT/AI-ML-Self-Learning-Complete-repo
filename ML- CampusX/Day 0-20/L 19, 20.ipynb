# %%
import pandas as pd

# %%
df = pd.read_csv('/content/sample_data/train.csv')

# %%
df.shape
# Out:
# (891, 12)

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 686          687         0       3              Panula, Mr. Jaako Arnold
# 796          797         1       1           Leader, Dr. Alice (Farnham)
# 870          871         0       3                     Balkic, Mr. Cerin
# 98            99         1       2  Doling, Mrs. John T (Ada Julia Bone)
# 863          864         0       3     Sage, Miss. Dorothy Edith "Dolly"
#
#         Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 686    male  14.0      4      1   3101295  39.6875   NaN        S
# 796  female  49.0      0      0     17465  25.9292   D17        S
# 870    male  26.0      0      0    349248   7.8958   NaN        S
# 98   female  34.0      0      1    231919  23.0000   NaN        S
# 863  female   NaN      8      2  CA. 2343  69.5500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.corr(numeric_only=True)['Survived']
# Out:
# PassengerId   -0.005007
# Survived       1.000000
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
# Parch          0.081629
# Fare           0.257307
# Name: Survived, dtype: float64

# %%
# Seaborn is a Python data visualization library based on Matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics. It is particularly useful for:
# - Creating complex visualizations easily.
# - Statistical plotting, for exploring relationships between multiple variables, visualizing distributions, and making comparisons.
# - Integration with Pandas DataFrames.
# - Aesthetic appeal with built-in themes and color palettes.

# %%
import seaborn as sns
sns.countplot(x='Survived', data=df)
sns.countplot(x='Sex', data=df)
# sns.countplot(df['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
import matplotlib.pyplot as plt
plt.hist(df['Age'],bins=15)
# Out:
# (array([ 44.,  24.,  32., 104., 115., 127.,  80.,  59.,  49.,  30.,  22.,
#          17.,   4.,   6.,   1.]),
#  array([ 0.42      ,  5.72533333, 11.03066667, 16.336     , 21.64133333,
#         26.94666667, 32.252     , 37.55733333, 42.86266667, 48.168     ,
#         53.47333333, 58.77866667, 64.084     , 69.38933333, 74.69466667,
#         80.        ]),
#  <BarContainer object of 15 artists>)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(df['Age'], kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.boxplot(x=df['Fare'])
# Out:
# <Axes: xlabel='Fare'>
